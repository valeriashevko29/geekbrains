# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
k1 = 1
k2 = 2
x1 = np.arange(1, 10, 0.1)
x2 = np.arange(1, 10, 0.1)
y1 = np.cos(k1 * x1)
y2 = np.cos(k2 * x2)
plt.plot(x1, y1, '-g', x2, y2, '-.b', linewidth = '1.5')
plt.show()
